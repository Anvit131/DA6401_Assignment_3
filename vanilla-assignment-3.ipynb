# %%
import wandb
wandb.login(key="5fb34431b405eb21dc0f263e5b3cf2c15fdc7471")
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ma24m004 (ma24m004-iit-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
import wandb
from torch.nn.utils.rnn import pad_sequence

# Encoder
class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, hidden_dim, n_layers, cell_type, dropout):
        super().__init__()
        self.embedding = nn.Embedding(input_dim, emb_dim)
        self.rnn = getattr(nn, cell_type)(emb_dim, hidden_dim, n_layers, dropout=dropout, batch_first=True)
        self.dropout = nn.Dropout(dropout)

    def forward(self, src):
        embedded = self.dropout(self.embedding(src))
        outputs, hidden = self.rnn(embedded)
        if isinstance(hidden, tuple):  # LSTM
            return hidden[0].contiguous(), hidden[1].contiguous()
        return hidden.contiguous(), None  # RNN, GRU

# Decoder
class Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim, hidden_dim, n_layers, cell_type, dropout):
        super().__init__()
        self.output_dim = output_dim
        self.embedding = nn.Embedding(output_dim, emb_dim)
        self.rnn = getattr(nn, cell_type)(emb_dim, hidden_dim, n_layers, dropout=dropout, batch_first=True)
        self.fc_out = nn.Linear(hidden_dim, output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, input, hidden, cell=None):
        input = input.unsqueeze(1)
        embedded = self.dropout(self.embedding(input))
        if cell is not None:
            hidden = hidden.contiguous()
            cell = cell.contiguous()
            output, (hidden, cell) = self.rnn(embedded, (hidden, cell))
        else:
            hidden = hidden.contiguous()
            output, hidden = self.rnn(embedded, hidden)
        prediction = self.fc_out(output.squeeze(1))
        return prediction, hidden, cell

# Seq2Seq Model with Beam Search
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.device = device

    def forward(self, src, trg, teacher_forcing_ratio=0.5):
        batch_size = src.shape[0]
        trg_len = trg.shape[1]
        trg_vocab_size = self.decoder.output_dim

        outputs = torch.zeros(batch_size, trg_len, trg_vocab_size).to(self.device)
        hidden, cell = self.encoder(src)

        input = trg[:, 0]
        for t in range(1, trg_len):
            output, hidden, cell = self.decoder(input, hidden, cell)
            outputs[:, t] = output
            teacher_force = np.random.random() < teacher_forcing_ratio
            top1 = output.argmax(1)
            input = trg[:, t] if teacher_force else top1
        return outputs

    def predict(self, src, max_len=30, beam_size=3):
        self.eval()
        batch_size = src.size(0)
        hidden, cell = self.encoder(src)
        outputs = []

        for i in range(batch_size):
            h = hidden[:, i:i+1].contiguous()
            c = cell[:, i:i+1].contiguous() if cell is not None else None
            beams = [(torch.tensor([1], device=self.device), 0.0, h, c)]  # [sequence, score, hidden, cell]
            for _ in range(max_len):
                new_beams = []
                for seq, score, h, c in beams:
                    input = seq[-1].unsqueeze(0)
                    output, h_new, c_new = self.decoder(input, h, c)
                    probs = torch.log_softmax(output, dim=1).squeeze(0)
                    topk = torch.topk(probs, beam_size)
                    for idx, prob in zip(topk.indices, topk.values):
                        new_seq = torch.cat([seq, idx.unsqueeze(0)])
                        new_beams.append((new_seq, score + prob.item(), h_new.contiguous(), c_new.contiguous() if c_new is not None else None))
                beams = sorted(new_beams, key=lambda x: x[1], reverse=True)[:beam_size]
                if beams[0][0][-1].item() == 2:  # Stop if <EOS>
                    break
            outputs.append(beams[0][0][1:])
        return outputs

# Dataset
class DakshinaDataset(Dataset):
    def __init__(self, data, input_vocab, output_vocab):
        self.data = data
        self.input_vocab = input_vocab
        self.output_vocab = output_vocab

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        src = [self.input_vocab.get(c, self.input_vocab['<UNK>']) for c in self.data.iloc[idx, 1]] + [self.input_vocab['<EOS>']]
        tgt = [self.output_vocab['<SOS>']] + [self.output_vocab.get(c, self.output_vocab['<UNK>']) for c in self.data.iloc[idx, 0]] + [self.output_vocab['<EOS>']]
        return torch.tensor(src), torch.tensor(tgt)

# Vocab Creation
def create_vocab(data, column):
    vocab = {'<PAD>': 0, '<SOS>': 1, '<EOS>': 2, '<UNK>': 3}
    for seq in data[column]:
        if pd.notna(seq):
            for char in seq:
                if char not in vocab:
                    vocab[char] = len(vocab)
    return vocab

# Collate
def pad_collate(batch):
    src_batch, tgt_batch = zip(*batch)
    src_padded = pad_sequence(src_batch, batch_first=True, padding_value=0)
    tgt_padded = pad_sequence(tgt_batch, batch_first=True, padding_value=0)
    return src_padded, tgt_padded

# %%
# Train
def train_model(config=None):
    with wandb.init(config=config):
        config = wandb.config
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        # Load data
        train_data = pd.read_csv('/kaggle/input/dakshina/dakshina_dataset_v1.0/hi/lexicons/hi.translit.sampled.train.tsv', sep='\t', header=None, dtype=str).dropna()
        dev_data = pd.read_csv('/kaggle/input/dakshina/dakshina_dataset_v1.0/hi/lexicons/hi.translit.sampled.dev.tsv', sep='\t', header=None, dtype=str).dropna()

        # Create vocabularies
        input_vocab = create_vocab(train_data, 1)  # English (source)
        output_vocab = create_vocab(train_data, 0)  # Hindi (target)

        # Prepare datasets and loaders
        train_dataset = DakshinaDataset(train_data, input_vocab, output_vocab)
        dev_dataset = DakshinaDataset(dev_data, input_vocab, output_vocab)
        train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, collate_fn=pad_collate)
        dev_loader = DataLoader(dev_dataset, batch_size=32, shuffle=False, collate_fn=pad_collate)

        # Initialize model
        encoder = Encoder(len(input_vocab), config.emb_dim, config.hidden_dim, config.num_layers, config.cell_type, config.dropout)
        decoder = Decoder(len(output_vocab), config.emb_dim, config.hidden_dim, config.num_layers, config.cell_type, config.dropout)
        model = Seq2Seq(encoder, decoder, device).to(device)

        # Loss and optimizer
        optimizer = optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.CrossEntropyLoss(ignore_index=0)

        best_val_accuracy = 0

        # Training loop
        for epoch in range(config.epochs):
            model.train()
            train_loss, train_correct, train_total = 0, 0, 0
            for src, tgt in train_loader:
                src, tgt = src.to(device), tgt.to(device)
                optimizer.zero_grad()
                output = model(src, tgt)
                output = output[:, 1:].reshape(-1, output.shape[-1])
                tgt = tgt[:, 1:].reshape(-1)
                loss = criterion(output, tgt)
                loss.backward()
                optimizer.step()

                train_loss += loss.item()
                preds = output.argmax(dim=1)
                non_pad_mask = tgt != 0
                train_correct += (preds == tgt)[non_pad_mask].sum().item()
                train_total += non_pad_mask.sum().item()

            train_accuracy = train_correct / train_total

            # Validation
            model.eval()
            val_loss, val_correct, val_total = 0, 0, 0
            with torch.no_grad():
                for src, tgt in dev_loader:
                    src, tgt = src.to(device), tgt.to(device)
                    output = model(src, tgt, teacher_forcing_ratio=0)
                    output = output[:, 1:].reshape(-1, output.shape[-1])
                    tgt = tgt[:, 1:].reshape(-1)
                    loss = criterion(output, tgt)
                    val_loss += loss.item()
                    preds = output.argmax(dim=1)
                    non_pad_mask = tgt != 0
                    val_correct += (preds == tgt)[non_pad_mask].sum().item()
                    val_total += non_pad_mask.sum().item()

            val_accuracy = val_correct / val_total
            patience_counter = 0
            # Save best model
            if val_accuracy > best_val_accuracy:
                best_val_accuracy = val_accuracy
                torch.save(model.state_dict(), '/kaggle/working/best_model.pt')
            else:
                patience_counter += 1
                if patience_counter >= 3:
                    print("Early stopping triggered.")
                    break

            # Log metrics to wandb
            wandb.log({
                'epoch': epoch,
                'train_loss': train_loss / len(train_loader),
                'val_loss': val_loss / len(dev_loader),
                'train_accuracy': train_accuracy,
                'val_accuracy': val_accuracy
            })

            # Log sample predictions
            src_sample, tgt_sample = next(iter(dev_loader))
            src_sample, tgt_sample = src_sample.to(device), tgt_sample.to(device)
            preds = model.predict(src_sample[:5], beam_size=config.beam_size)

            inv_input_vocab = {v: k for k, v in input_vocab.items()}
            inv_output_vocab = {v: k for k, v in output_vocab.items()}
            table = wandb.Table(columns=["Input", "Target", "Prediction"])
            for i in range(len(preds)):
                input_str = ''.join([inv_input_vocab.get(id.item(), '?') for id in src_sample[i] if id.item() not in [0, input_vocab['<EOS>']]])
                target_str = ''.join([inv_output_vocab.get(id.item(), '?') for id in tgt_sample[i] if id.item() not in [0, output_vocab['<EOS>']]])
                pred_str = ''.join([inv_output_vocab.get(id.item(), '?') for id in preds[i]])
                table.add_data(input_str, target_str, pred_str)
            wandb.log({"Predictions": table})

# %%
# Sweep
sweep_config = {
    'method': 'random',
    'metric': {'name': 'val_accuracy', 'goal': 'maximize'},
    'parameters': {
        'emb_dim': {'values': [16, 32, 64, 256]},
        'hidden_dim': {'values': [16, 32, 64, 256]},
        'num_layers': {'values': [1, 2, 3]},
        'cell_type': {'values': ['RNN', 'GRU', 'LSTM']},
        'dropout': {'values': [0, 0.2, 0.3]},
        'epochs': {'values': [5, 10]},
        'beam_size': {'values': [1, 3, 5]}
    }
}

sweep_id = wandb.sweep(sweep_config, project='DL_ASSIGNMENT_3_RNN')
wandb.agent(sweep_id, train_model, count=60)
wandb.finish()
# Out:
# Create sweep with ID: pd9x2ajs
# Sweep URL: https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs
# wandb: Agent Starting Run: krv2nmsb with config:
# wandb: 	beam_size: 1
# wandb: 	cell_type: GRU
# wandb: 	dropout: 0
# wandb: 	emb_dim: 16
# wandb: 	epochs: 10
# wandb: 	hidden_dim: 16
# wandb: 	num_layers: 3
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_084325-krv2nmsb</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/krv2nmsb' target="_blank">light-sweep-1</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/krv2nmsb' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/krv2nmsb</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▂▄▅▅▆▇▇██</td></tr><tr><td>train_loss</td><td>█▆▅▄▃▃▂▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▃▄▅▆▇▇██</td></tr><tr><td>val_loss</td><td>█▇▅▄▃▃▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_accuracy</td><td>0.51096</td></tr><tr><td>train_loss</td><td>1.70208</td></tr><tr><td>val_accuracy</td><td>0.46767</td></tr><tr><td>val_loss</td><td>1.88986</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">light-sweep-1</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/krv2nmsb' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/krv2nmsb</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 10 media file(s), 20 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_084325-krv2nmsb/logs</code>
# wandb: Agent Starting Run: daggptac with config:
# wandb: 	beam_size: 5
# wandb: 	cell_type: RNN
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 32
# wandb: 	epochs: 5
# wandb: 	hidden_dim: 16
# wandb: 	num_layers: 3
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_084940-daggptac</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/daggptac' target="_blank">prime-sweep-2</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/daggptac' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/daggptac</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_accuracy</td><td>▁▅▆▇█</td></tr><tr><td>train_loss</td><td>█▃▂▂▁</td></tr><tr><td>val_accuracy</td><td>▁▄███</td></tr><tr><td>val_loss</td><td>█▅▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_accuracy</td><td>0.24528</td></tr><tr><td>train_loss</td><td>2.86821</td></tr><tr><td>val_accuracy</td><td>0.21969</td></tr><tr><td>val_loss</td><td>3.021</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">prime-sweep-2</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/daggptac' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/daggptac</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 5 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_084940-daggptac/logs</code>
# wandb: Agent Starting Run: kityiqav with config:
# wandb: 	beam_size: 3
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 32
# wandb: 	epochs: 5
# wandb: 	hidden_dim: 32
# wandb: 	num_layers: 3
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_085232-kityiqav</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/kityiqav' target="_blank">stellar-sweep-3</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/kityiqav' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/kityiqav</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_accuracy</td><td>▁▃▅▇█</td></tr><tr><td>train_loss</td><td>█▆▄▂▁</td></tr><tr><td>val_accuracy</td><td>▁▃▆▇█</td></tr><tr><td>val_loss</td><td>█▆▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_accuracy</td><td>0.46836</td></tr><tr><td>train_loss</td><td>1.85042</td></tr><tr><td>val_accuracy</td><td>0.45897</td></tr><tr><td>val_loss</td><td>1.86345</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stellar-sweep-3</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/kityiqav' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/kityiqav</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 5 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_085232-kityiqav/logs</code>
# wandb: Agent Starting Run: d91ku0oa with config:
# wandb: 	beam_size: 3
# wandb: 	cell_type: RNN
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 64
# wandb: 	epochs: 10
# wandb: 	hidden_dim: 64
# wandb: 	num_layers: 3
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_085610-d91ku0oa</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/d91ku0oa' target="_blank">colorful-sweep-4</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/d91ku0oa' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/d91ku0oa</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▅▆▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▇▇▅█▆▆▇█</td></tr><tr><td>val_loss</td><td>█▄▂▁▃▁▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_accuracy</td><td>0.26538</td></tr><tr><td>train_loss</td><td>2.7159</td></tr><tr><td>val_accuracy</td><td>0.22605</td></tr><tr><td>val_loss</td><td>2.94219</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">colorful-sweep-4</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/d91ku0oa' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/d91ku0oa</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 10 media file(s), 20 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_085610-d91ku0oa/logs</code>
# wandb: Agent Starting Run: 1n7yz9wm with config:
# wandb: 	beam_size: 3
# wandb: 	cell_type: GRU
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 32
# wandb: 	epochs: 5
# wandb: 	hidden_dim: 32
# wandb: 	num_layers: 2
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_090149-1n7yz9wm</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/1n7yz9wm' target="_blank">silver-sweep-5</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/1n7yz9wm' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/1n7yz9wm</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_accuracy</td><td>▁▄▆▇█</td></tr><tr><td>train_loss</td><td>█▅▃▂▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆▇█</td></tr><tr><td>val_loss</td><td>█▅▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_accuracy</td><td>0.4867</td></tr><tr><td>train_loss</td><td>1.73923</td></tr><tr><td>val_accuracy</td><td>0.48681</td></tr><tr><td>val_loss</td><td>1.73488</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">silver-sweep-5</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/1n7yz9wm' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/1n7yz9wm</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 5 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_090149-1n7yz9wm/logs</code>
# wandb: Agent Starting Run: n8uskvhs with config:
# wandb: 	beam_size: 3
# wandb: 	cell_type: RNN
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 64
# wandb: 	epochs: 10
# wandb: 	hidden_dim: 64
# wandb: 	num_layers: 3
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_090447-n8uskvhs</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/n8uskvhs' target="_blank">valiant-sweep-6</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/n8uskvhs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/n8uskvhs</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▄▆▆▇▇▇▇█▇</td></tr><tr><td>train_loss</td><td>█▄▃▃▂▂▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▄▅▆▇▄▅▇█</td></tr><tr><td>val_loss</td><td>█▄▄▄▂▁▃▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_accuracy</td><td>0.27507</td></tr><tr><td>train_loss</td><td>2.6867</td></tr><tr><td>val_accuracy</td><td>0.24838</td></tr><tr><td>val_loss</td><td>2.85513</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">valiant-sweep-6</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/n8uskvhs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/n8uskvhs</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 10 media file(s), 20 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_090447-n8uskvhs/logs</code>
# wandb: Agent Starting Run: eziys4zb with config:
# wandb: 	beam_size: 1
# wandb: 	cell_type: GRU
# wandb: 	dropout: 0
# wandb: 	emb_dim: 32
# wandb: 	epochs: 10
# wandb: 	hidden_dim: 16
# wandb: 	num_layers: 2
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_091011-eziys4zb</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/eziys4zb' target="_blank">curious-sweep-7</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/eziys4zb' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/eziys4zb</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▃▅▆▆▇▇▇██</td></tr><tr><td>train_loss</td><td>█▅▄▃▂▂▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▄▅▆▇▇▇██</td></tr><tr><td>val_loss</td><td>█▆▄▃▃▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_accuracy</td><td>0.46552</td></tr><tr><td>train_loss</td><td>1.89394</td></tr><tr><td>val_accuracy</td><td>0.41351</td></tr><tr><td>val_loss</td><td>2.12707</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">curious-sweep-7</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/eziys4zb' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/eziys4zb</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 10 media file(s), 20 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_091011-eziys4zb/logs</code>
# wandb: Agent Starting Run: jkipv6s1 with config:
# wandb: 	beam_size: 1
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 16
# wandb: 	epochs: 10
# wandb: 	hidden_dim: 32
# wandb: 	num_layers: 1
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_091531-jkipv6s1</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/jkipv6s1' target="_blank">lemon-sweep-8</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/jkipv6s1' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/jkipv6s1</a>
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn(
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▃▄▅▆▆▇▇██</td></tr><tr><td>train_loss</td><td>█▆▅▄▃▂▂▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▄▅▆▆▇▇██</td></tr><tr><td>val_loss</td><td>█▆▅▄▃▃▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_accuracy</td><td>0.4941</td></tr><tr><td>train_loss</td><td>1.70071</td></tr><tr><td>val_accuracy</td><td>0.45916</td></tr><tr><td>val_loss</td><td>1.82521</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lemon-sweep-8</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/jkipv6s1' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/jkipv6s1</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 10 media file(s), 20 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_091531-jkipv6s1/logs</code>
# wandb: Agent Starting Run: do1f2u9n with config:
# wandb: 	beam_size: 3
# wandb: 	cell_type: GRU
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 64
# wandb: 	epochs: 10
# wandb: 	hidden_dim: 64
# wandb: 	num_layers: 3
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_092025-do1f2u9n</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/do1f2u9n' target="_blank">electric-sweep-9</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/do1f2u9n' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/do1f2u9n</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▅▆▇▇▇████</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆▆▇▇████</td></tr><tr><td>val_loss</td><td>█▄▃▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_accuracy</td><td>0.73982</td></tr><tr><td>train_loss</td><td>0.84941</td></tr><tr><td>val_accuracy</td><td>0.67849</td></tr><tr><td>val_loss</td><td>1.12693</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">electric-sweep-9</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/do1f2u9n' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/do1f2u9n</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 10 media file(s), 16 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_092025-do1f2u9n/logs</code>
# wandb: Agent Starting Run: 62btgdkr with config:
# wandb: 	beam_size: 1
# wandb: 	cell_type: GRU
# wandb: 	dropout: 0
# wandb: 	emb_dim: 256
# wandb: 	epochs: 10
# wandb: 	hidden_dim: 32
# wandb: 	num_layers: 1
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_092705-62btgdkr</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/62btgdkr' target="_blank">fallen-sweep-10</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/62btgdkr' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/62btgdkr</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▄▅▆▇▇▇███</td></tr><tr><td>train_loss</td><td>█▅▄▃▂▂▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▆▇▇████</td></tr><tr><td>val_loss</td><td>█▅▄▃▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_accuracy</td><td>0.46095</td></tr><tr><td>train_loss</td><td>1.80774</td></tr><tr><td>val_accuracy</td><td>0.39471</td></tr><tr><td>val_loss</td><td>2.08209</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fallen-sweep-10</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/62btgdkr' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/62btgdkr</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 10 media file(s), 20 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_092705-62btgdkr/logs</code>
# wandb: Agent Starting Run: g5a4juxs with config:
# wandb: 	beam_size: 1
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0
# wandb: 	emb_dim: 16
# wandb: 	epochs: 5
# wandb: 	hidden_dim: 16
# wandb: 	num_layers: 1
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_093133-g5a4juxs</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/g5a4juxs' target="_blank">vivid-sweep-11</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/g5a4juxs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/g5a4juxs</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_accuracy</td><td>▁▅▆▇█</td></tr><tr><td>train_loss</td><td>█▄▃▂▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▅█</td></tr><tr><td>val_loss</td><td>█▆▄▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_accuracy</td><td>0.30315</td></tr><tr><td>train_loss</td><td>2.56054</td></tr><tr><td>val_accuracy</td><td>0.26161</td></tr><tr><td>val_loss</td><td>2.77817</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vivid-sweep-11</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/g5a4juxs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/g5a4juxs</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 5 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_093133-g5a4juxs/logs</code>
# wandb: Agent Starting Run: vyd10e69 with config:
# wandb: 	beam_size: 5
# wandb: 	cell_type: RNN
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 16
# wandb: 	epochs: 10
# wandb: 	hidden_dim: 32
# wandb: 	num_layers: 3
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_093401-vyd10e69</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/vyd10e69' target="_blank">smooth-sweep-12</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/vyd10e69' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/vyd10e69</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▄▆▇▇▇▇▇▇█</td></tr><tr><td>train_loss</td><td>█▄▃▂▁▁▂▂▂▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆█▅█▆▅▇▅</td></tr><tr><td>val_loss</td><td>█▆▃▁▄▂▃▄▃▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_accuracy</td><td>0.256</td></tr><tr><td>train_loss</td><td>2.80947</td></tr><tr><td>val_accuracy</td><td>0.21457</td></tr><tr><td>val_loss</td><td>3.03175</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">smooth-sweep-12</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/vyd10e69' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/vyd10e69</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 10 media file(s), 20 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_093401-vyd10e69/logs</code>
# wandb: Agent Starting Run: i7ub1zxo with config:
# wandb: 	beam_size: 3
# wandb: 	cell_type: RNN
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 16
# wandb: 	epochs: 5
# wandb: 	hidden_dim: 256
# wandb: 	num_layers: 2
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_093925-i7ub1zxo</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/i7ub1zxo' target="_blank">morning-sweep-13</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/i7ub1zxo' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/i7ub1zxo</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_accuracy</td><td>▁▄▆▇█</td></tr><tr><td>train_loss</td><td>█▅▃▂▁</td></tr><tr><td>val_accuracy</td><td>▃▁▂▅█</td></tr><tr><td>val_loss</td><td>▇█▆▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_accuracy</td><td>0.27279</td></tr><tr><td>train_loss</td><td>2.67694</td></tr><tr><td>val_accuracy</td><td>0.23704</td></tr><tr><td>val_loss</td><td>2.93087</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">morning-sweep-13</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/i7ub1zxo' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/i7ub1zxo</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 5 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_093925-i7ub1zxo/logs</code>
# wandb: Agent Starting Run: 3nlcu3xs with config:
# wandb: 	beam_size: 5
# wandb: 	cell_type: GRU
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 16
# wandb: 	epochs: 5
# wandb: 	hidden_dim: 64
# wandb: 	num_layers: 1
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_094222-3nlcu3xs</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/3nlcu3xs' target="_blank">soft-sweep-14</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/3nlcu3xs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/3nlcu3xs</a>
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn(
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_accuracy</td><td>▁▄▆▇█</td></tr><tr><td>train_loss</td><td>█▅▃▂▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆▇█</td></tr><tr><td>val_loss</td><td>█▅▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_accuracy</td><td>0.55941</td></tr><tr><td>train_loss</td><td>1.47354</td></tr><tr><td>val_accuracy</td><td>0.53816</td></tr><tr><td>val_loss</td><td>1.55123</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">soft-sweep-14</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/3nlcu3xs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/3nlcu3xs</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 5 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_094222-3nlcu3xs/logs</code>
# wandb: Agent Starting Run: kp7law0l with config:
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	epochs: 5
# wandb: 	hidden_dim: 16
# wandb: 	num_layers: 1
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_094505-kp7law0l</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/kp7law0l' target="_blank">treasured-sweep-15</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/kp7law0l' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/kp7law0l</a>
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn(
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_accuracy</td><td>▁▄▆██</td></tr><tr><td>train_loss</td><td>█▅▃▂▁</td></tr><tr><td>val_accuracy</td><td>▁▆▇██</td></tr><tr><td>val_loss</td><td>█▅▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_accuracy</td><td>0.29671</td></tr><tr><td>train_loss</td><td>2.57123</td></tr><tr><td>val_accuracy</td><td>0.2565</td></tr><tr><td>val_loss</td><td>2.7822</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">treasured-sweep-15</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/kp7law0l' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/kp7law0l</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 5 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_094505-kp7law0l/logs</code>
# wandb: Agent Starting Run: wucczmap with config:
# wandb: 	beam_size: 1
# wandb: 	cell_type: GRU
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 256
# wandb: 	epochs: 5
# wandb: 	hidden_dim: 32
# wandb: 	num_layers: 3
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_094742-wucczmap</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/wucczmap' target="_blank">radiant-sweep-16</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/wucczmap' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/wucczmap</a>
# ...
#  View run <strong style="color:#cdcd00">avid-sweep-55</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/6dq6yrff' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/6dq6yrff</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 5 media file(s), 6 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_122309-6dq6yrff/logs</code>
# wandb: Agent Starting Run: prj57ist with config:
# wandb: 	beam_size: 3
# wandb: 	cell_type: GRU
# wandb: 	dropout: 0.2
# wandb: 	emb_dim: 16
# wandb: 	epochs: 10
# wandb: 	hidden_dim: 256
# wandb: 	num_layers: 1
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_122546-prj57ist</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/prj57ist' target="_blank">ancient-sweep-56</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/prj57ist' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/prj57ist</a>
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn(
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▅▆▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▆▆▇█████</td></tr><tr><td>val_loss</td><td>█▄▂▂▁▁▁▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_accuracy</td><td>0.84043</td></tr><tr><td>train_loss</td><td>0.52321</td></tr><tr><td>val_accuracy</td><td>0.69386</td></tr><tr><td>val_loss</td><td>1.12716</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ancient-sweep-56</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/prj57ist' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/prj57ist</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 10 media file(s), 14 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_122546-prj57ist/logs</code>
# wandb: Agent Starting Run: wtn6je29 with config:
# wandb: 	beam_size: 3
# wandb: 	cell_type: RNN
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 64
# wandb: 	epochs: 5
# wandb: 	hidden_dim: 32
# wandb: 	num_layers: 2
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_123040-wtn6je29</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/wtn6je29' target="_blank">efficient-sweep-57</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/wtn6je29' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/wtn6je29</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>train_accuracy</td><td>▁▅▆▇█</td></tr><tr><td>train_loss</td><td>█▄▃▂▁</td></tr><tr><td>val_accuracy</td><td>▁▅▆▄█</td></tr><tr><td>val_loss</td><td>█▅▅▄▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>train_accuracy</td><td>0.24527</td></tr><tr><td>train_loss</td><td>2.86508</td></tr><tr><td>val_accuracy</td><td>0.20286</td></tr><tr><td>val_loss</td><td>3.08607</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">efficient-sweep-57</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/wtn6je29' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/wtn6je29</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 5 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_123040-wtn6je29/logs</code>
# wandb: Agent Starting Run: vwl6tx81 with config:
# wandb: 	beam_size: 1
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 64
# wandb: 	epochs: 10
# wandb: 	hidden_dim: 256
# wandb: 	num_layers: 3
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_123317-vwl6tx81</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/vwl6tx81' target="_blank">misunderstood-sweep-58</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/vwl6tx81' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/vwl6tx81</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▅▆▇▇▇████</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▆▇▇█████</td></tr><tr><td>val_loss</td><td>█▃▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_accuracy</td><td>0.87349</td></tr><tr><td>train_loss</td><td>0.41591</td></tr><tr><td>val_accuracy</td><td>0.73123</td></tr><tr><td>val_loss</td><td>1.06099</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">misunderstood-sweep-58</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/vwl6tx81' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/vwl6tx81</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 10 media file(s), 18 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_123317-vwl6tx81/logs</code>
# wandb: Agent Starting Run: zjw5zoye with config:
# wandb: 	beam_size: 5
# wandb: 	cell_type: LSTM
# wandb: 	dropout: 0
# wandb: 	emb_dim: 64
# wandb: 	epochs: 10
# wandb: 	hidden_dim: 32
# wandb: 	num_layers: 1
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_124057-zjw5zoye</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/zjw5zoye' target="_blank">helpful-sweep-59</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/zjw5zoye' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/zjw5zoye</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▃▄▅▆▆▇▇██</td></tr><tr><td>train_loss</td><td>█▆▄▄▃▂▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▄▅▆▆▇▇██</td></tr><tr><td>val_loss</td><td>█▆▅▄▃▂▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_accuracy</td><td>0.57864</td></tr><tr><td>train_loss</td><td>1.40791</td></tr><tr><td>val_accuracy</td><td>0.48845</td></tr><tr><td>val_loss</td><td>1.74818</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">helpful-sweep-59</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/zjw5zoye' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/zjw5zoye</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 10 media file(s), 20 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_124057-zjw5zoye/logs</code>
# wandb: Agent Starting Run: iuvhz5nx with config:
# wandb: 	beam_size: 5
# wandb: 	cell_type: GRU
# wandb: 	dropout: 0.3
# wandb: 	emb_dim: 64
# wandb: 	epochs: 10
# wandb: 	hidden_dim: 64
# wandb: 	num_layers: 3
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_124546-iuvhz5nx</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/iuvhz5nx' target="_blank">ethereal-sweep-60</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View sweep at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/sweeps/pd9x2ajs</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/iuvhz5nx' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/iuvhz5nx</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train_accuracy</td><td>▁▄▆▆▇▇▇███</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▆▆▇▇████</td></tr><tr><td>val_loss</td><td>█▄▃▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>train_accuracy</td><td>0.70723</td></tr><tr><td>train_loss</td><td>0.94979</td></tr><tr><td>val_accuracy</td><td>0.65576</td></tr><tr><td>val_loss</td><td>1.15449</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ethereal-sweep-60</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/iuvhz5nx' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/iuvhz5nx</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 10 media file(s), 12 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_124546-iuvhz5nx/logs</code>

# %%
import random
import torch
from torch.utils.data import DataLoader
import pandas as pd
import wandb
from IPython.display import display, HTML

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Initialize Wandb
wandb.init(project="DL_ASSIGNMENT_3_RNN", name="vanilla-test-inference")

# Load train data to recreate vocabularies
train_data = pd.read_csv(
    '/kaggle/input/dakshina/dakshina_dataset_v1.0/hi/lexicons/hi.translit.sampled.train.tsv',
    sep='\t', header=None, dtype=str).dropna()

# Create vocabularies
input_vocab = create_vocab(train_data, 1)  # English
output_vocab = create_vocab(train_data, 0)  # Hindi
inv_input_vocab = {v: k for k, v in input_vocab.items()}
inv_output_vocab = {v: k for k, v in output_vocab.items()}

# Load test data
test_data = pd.read_csv(
    '/kaggle/input/dakshina/dakshina_dataset_v1.0/hi/lexicons/hi.translit.sampled.test.tsv',
    sep='\t', header=None, dtype=str).dropna()
test_dataset = DakshinaDataset(test_data, input_vocab, output_vocab)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, collate_fn=pad_collate)

# Model Config
emb_dim = 64
hidden_dim = 256
num_layers = 3
cell_type = 'LSTM'
dropout = 0.3
beam_size = 3

# Instantiate and Load Model
encoder = Encoder(len(input_vocab), emb_dim, hidden_dim, num_layers, cell_type, dropout)
decoder = Decoder(len(output_vocab), emb_dim, hidden_dim, num_layers, cell_type, dropout)
model = Seq2Seq(encoder, decoder, device).to(device)
model.load_state_dict(torch.load('/kaggle/working/best_model.pt', map_location=device, weights_only=True))
model.eval()

# Inference
correct_words = 0
total_words = 0
total_correct_chars = 0
total_chars = 0
predictions = []

with torch.no_grad():
    for src, tgt in test_loader:
        src, tgt = src.to(device), tgt.to(device)
        batch_size = src.size(0)
        preds = model.predict(src, max_len=30, beam_size=beam_size)

        for i in range(batch_size):
            pred_indices = preds[i].tolist()
            if 2 in pred_indices:
                pred_indices = pred_indices[:pred_indices.index(2)]
            pred_str = ''.join([inv_output_vocab.get(idx, '?') for idx in pred_indices])

            tgt_indices = tgt[i, 1:].tolist()
            if 2 in tgt_indices:
                tgt_indices = tgt_indices[:tgt_indices.index(2)]
            tgt_str = ''.join([inv_output_vocab.get(idx, '?') for idx in tgt_indices])

            input_indices = src[i].tolist()
            input_str = ''.join([inv_input_vocab.get(idx, '?') for idx in input_indices if idx not in [0, input_vocab['<EOS>']]])

            is_correct_word = pred_str == tgt_str
            correct_words += is_correct_word
            total_words += 1

            correct_chars_sample = sum(1 for p, t in zip(pred_str, tgt_str) if p == t)
            total_correct_chars += correct_chars_sample
            total_chars += len(tgt_str)

            predictions.append({
                'input': input_str,
                'target': tgt_str,
                'prediction': pred_str,
                'correct_word': is_correct_word,
                'correct_chars': correct_chars_sample,
                'total_chars': len(tgt_str)
            })

# Accuracies
word_accuracy = (correct_words / total_words) * 100
char_accuracy = (total_correct_chars / total_chars) * 100 if total_chars > 0 else 0

# Log metrics to Wandb
wandb.log({
    "test_word_accuracy": word_accuracy,
    "test_char_accuracy": char_accuracy
})

print(f"\nTest Word Accuracy: {word_accuracy:.2f}%")
print(f"Test Character Accuracy: {char_accuracy:.2f}%")

# Convert predictions to DataFrame
df_predictions = pd.DataFrame(predictions)

# Save All Predictions - CSV (no color)
csv_path = '/kaggle/working/predictions_vanilla.csv'
df_predictions.to_csv(csv_path, index=False)
print(f"CSV saved to {csv_path}")

# Save All Predictions - HTML (no color)
all_html_path = '/kaggle/working/predictions_all.html'
df_predictions.to_html(all_html_path, index=False)
print(f"All HTML (no color) saved to {all_html_path}")

# Color Function for Sample
def highlight_row(row):
    color = 'background-color: #d4edda;' if row['correct_word'] else 'background-color: #f8d7da;'
    return [color] * len(row)

# Save Sample Predictions - HTML (colored)
sample_df = df_predictions.sample(n=min(10, len(df_predictions)), random_state=42)
styled_sample = sample_df.style.apply(highlight_row, axis=1)\
    .set_table_styles([{'selector': 'th', 'props': [('text-align', 'center')]}])\
    .set_properties(**{
        'text-align': 'left',
        'padding': '8px',
        'font-size': '14px',
        'border': '1px solid #ccc'
    }).hide(axis="index")

sample_html_path = '/kaggle/working/predictions_sample_colored.html'
with open(sample_html_path, 'w', encoding='utf-8') as f:
    f.write(f"<h3>Sample Predictions (Color-Coded)</h3>\n{styled_sample.to_html()}")
print(f"Sample colored HTML saved to {sample_html_path}")

# Log to Wandb
artifact = wandb.Artifact('predictions_vanilla', type='predictions')
artifact.add_file(csv_path)
artifact.add_file(all_html_path)
artifact.add_file(sample_html_path)
wandb.log_artifact(artifact)

# Display Sample in Notebook
display(HTML("<h3>Vanilla Sample Predictions (Color-Coded)</h3>"))
display(styled_sample)

# Finish Wandb
wandb.finish()

# %% [markdown]
# ## Setup For Devanagari Lipi

# %%
# !fc-list | grep Devanagari

# %%
# !wget https://noto-website-2.storage.googleapis.com/pkgs/NotoSansDevanagari-hinted.zip
# !unzip NotoSansDevanagari-hinted.zip
# Out:
# --2025-05-19 16:03:53--  https://noto-website-2.storage.googleapis.com/pkgs/NotoSansDevanagari-hinted.zip
# Resolving noto-website-2.storage.googleapis.com (noto-website-2.storage.googleapis.com)... 142.250.125.207, 173.194.194.207, 142.251.184.207, ...
# Connecting to noto-website-2.storage.googleapis.com (noto-website-2.storage.googleapis.com)|142.250.125.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6201435 (5.9M) [application/zip]
# Saving to: ‘NotoSansDevanagari-hinted.zip’
#
# NotoSansDevanagari- 100%[===================>]   5.91M  --.-KB/s    in 0.09s
#
# 2025-05-19 16:03:54 (66.5 MB/s) - ‘NotoSansDevanagari-hinted.zip’ saved [6201435/6201435]
#
# Archive:  NotoSansDevanagari-hinted.zip
#   inflating: LICENSE_OFL.txt
#   inflating: NotoSansDevanagari-Black.ttf
#   inflating: NotoSansDevanagari-Bold.ttf
#   inflating: NotoSansDevanagari-Condensed.ttf
#   inflating: NotoSansDevanagari-CondensedBlack.ttf
#   inflating: NotoSansDevanagari-CondensedBold.ttf
#   inflating: NotoSansDevanagari-CondensedExtraBold.ttf
#   inflating: NotoSansDevanagari-CondensedExtraLight.ttf
#   inflating: NotoSansDevanagari-CondensedLight.ttf
#   inflating: NotoSansDevanagari-CondensedMedium.ttf
#   inflating: NotoSansDevanagari-CondensedSemiBold.ttf
#   inflating: NotoSansDevanagari-CondensedThin.ttf
#   inflating: NotoSansDevanagari-ExtraBold.ttf
#   inflating: NotoSansDevanagari-ExtraCondensed.ttf
#   inflating: NotoSansDevanagari-ExtraCondensedBlack.ttf
#   inflating: NotoSansDevanagari-ExtraCondensedBold.ttf
#   inflating: NotoSansDevanagari-ExtraCondensedExtraBold.ttf
#   inflating: NotoSansDevanagari-ExtraCondensedExtraLight.ttf
#   inflating: NotoSansDevanagari-ExtraCondensedLight.ttf
#   inflating: NotoSansDevanagari-ExtraCondensedMedium.ttf
#   inflating: NotoSansDevanagari-ExtraCondensedSemiBold.ttf
#   inflating: NotoSansDevanagari-ExtraCondensedThin.ttf
#   inflating: NotoSansDevanagari-ExtraLight.ttf
#   inflating: NotoSansDevanagari-Light.ttf
#   inflating: NotoSansDevanagari-Medium.ttf
#   inflating: NotoSansDevanagari-Regular.ttf
#   inflating: NotoSansDevanagari-SemiBold.ttf
#   inflating: NotoSansDevanagari-SemiCondensed.ttf
#   inflating: NotoSansDevanagari-SemiCondensedBlack.ttf
#   inflating: NotoSansDevanagari-SemiCondensedBold.ttf
#   inflating: NotoSansDevanagari-SemiCondensedExtraBold.ttf
#   inflating: NotoSansDevanagari-SemiCondensedExtraLight.ttf
#   inflating: NotoSansDevanagari-SemiCondensedLight.ttf
#   inflating: NotoSansDevanagari-SemiCondensedMedium.ttf
#   inflating: NotoSansDevanagari-SemiCondensedSemiBold.ttf
#   inflating: NotoSansDevanagari-SemiCondensedThin.ttf
#   inflating: NotoSansDevanagari-Thin.ttf
#   inflating: NotoSansDevanagariUI-Black.ttf
#   inflating: NotoSansDevanagariUI-Bold.ttf
#   inflating: NotoSansDevanagariUI-Condensed.ttf
#   inflating: NotoSansDevanagariUI-CondensedBlack.ttf
#   inflating: NotoSansDevanagariUI-CondensedBold.ttf
#   inflating: NotoSansDevanagariUI-CondensedExtraBold.ttf
#   inflating: NotoSansDevanagariUI-CondensedExtraLight.ttf
#   inflating: NotoSansDevanagariUI-CondensedLight.ttf
#   inflating: NotoSansDevanagariUI-CondensedMedium.ttf
#   inflating: NotoSansDevanagariUI-CondensedSemiBold.ttf
#   inflating: NotoSansDevanagariUI-CondensedThin.ttf
#   inflating: NotoSansDevanagariUI-ExtraBold.ttf
#   inflating: NotoSansDevanagariUI-ExtraCondensed.ttf
#   inflating: NotoSansDevanagariUI-ExtraCondensedBlack.ttf
#   inflating: NotoSansDevanagariUI-ExtraCondensedBold.ttf
#   inflating: NotoSansDevanagariUI-ExtraCondensedExtraBold.ttf
#   inflating: NotoSansDevanagariUI-ExtraCondensedExtraLight.ttf
#   inflating: NotoSansDevanagariUI-ExtraCondensedLight.ttf
#   inflating: NotoSansDevanagariUI-ExtraCondensedMedium.ttf
#   inflating: NotoSansDevanagariUI-ExtraCondensedSemiBold.ttf
#   inflating: NotoSansDevanagariUI-ExtraCondensedThin.ttf
#   inflating: NotoSansDevanagariUI-ExtraLight.ttf
#   inflating: NotoSansDevanagariUI-Light.ttf
#   inflating: NotoSansDevanagariUI-Medium.ttf
#   inflating: NotoSansDevanagariUI-Regular.ttf
#   inflating: NotoSansDevanagariUI-SemiBold.ttf
#   inflating: NotoSansDevanagariUI-SemiCondensed.ttf
#   inflating: NotoSansDevanagariUI-SemiCondensedBlack.ttf
#   inflating: NotoSansDevanagariUI-SemiCondensedBold.ttf
#   inflating: NotoSansDevanagariUI-SemiCondensedExtraBold.ttf
#   inflating: NotoSansDevanagariUI-SemiCondensedExtraLight.ttf
#   inflating: NotoSansDevanagariUI-SemiCondensedLight.ttf
#   inflating: NotoSansDevanagariUI-SemiCondensedMedium.ttf
#   inflating: NotoSansDevanagariUI-SemiCondensedSemiBold.ttf
#   inflating: NotoSansDevanagariUI-SemiCondensedThin.ttf
#   inflating: NotoSansDevanagariUI-Thin.ttf
#   inflating: README

# %%
import os
import matplotlib.pyplot as plt
from matplotlib import font_manager, rcParams

# Use 'Agg' backend for non-GUI environments (optional but safe)
import matplotlib
matplotlib.use("Agg")

# Path to the Noto Sans Devanagari font (adjust if needed)
font_path = "/kaggle/input/notosans-devanagiri/static/NotoSansDevanagari-Regular.ttf"

if os.path.exists(font_path):
    font_manager.fontManager.addfont(font_path)
    dev_font = font_manager.FontProperties(fname=font_path)
    rcParams['font.family'] = dev_font.get_name()
    print(f"✅ Loaded font: {dev_font.get_name()}")
else:
    print("❌ Devanagari font not found. Falling back to default.")
    dev_font = None

# Test plot to render "भारत"
plt.figure(figsize=(6, 2))
plt.text(0.5, 0.5, "भारत", fontsize=30, ha='center', fontproperties=dev_font)
plt.title("Test: Devanagari Font Rendering", fontproperties=dev_font)
plt.axis('off')
plt.tight_layout()
plt.savefig("/kaggle/working/devanagari_test.png")
plt.show()
# Out:
# ✅ Loaded font: Noto Sans Devanagari

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.font_manager as fm
import wandb

# Initialize WandB (if not already initialized)
wandb.init(project="DL_ASSIGNMENT_3_RNN", name="char-wise-confusion", reinit=True)

# Font for Hindi (Devanagari)
font_path = "/kaggle/input/notosans-devanagiri/static/NotoSansDevanagari-Regular.ttf"
prop = fm.FontProperties(fname=font_path)
plt.rcParams['font.family'] = prop.get_name()

# Sample 10 rows from the predictions DataFrame
sample_df = df_predictions.sample(n=10, random_state=42)

# Set up a 4x3 grid of plots
fig, axes = plt.subplots(4, 3, figsize=(18, 20))
axes = axes.flatten()

for idx, row in enumerate(sample_df.itertuples()):
    target = list(row.target)
    pred = list(row.prediction)

    # Pad shorter sequence with "_" to make lengths match
    max_len = max(len(target), len(pred))
    target += ['_'] * (max_len - len(target))
    pred += ['_'] * (max_len - len(pred))

    labels = sorted(set(target + pred))
    cm = confusion_matrix(target, pred, labels=labels)

    ax = axes[idx]
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',  # Changed colormap here
                xticklabels=labels, yticklabels=labels, ax=ax, cbar=True,
                annot_kws={"size": 10, "weight": 'bold', "color": "black"})

    # Add titles with corresponding word strings
    ax.set_title(f"Sample {idx + 1}\nTarget: {row.target}\nPred: {row.prediction}",
                 fontproperties=prop, fontsize=10, color='black')
    ax.set_xlabel("Predicted", fontproperties=prop, color='black')
    ax.set_ylabel("Target", fontproperties=prop, color='black')
    ax.tick_params(axis='x', rotation=45, labelsize=9)
    ax.tick_params(axis='y', rotation=0, labelsize=9)

# Hide any unused subplots
for j in range(len(sample_df), len(axes)):
    fig.delaxes(axes[j])

# Save figure
plt.tight_layout()
char_confusion_path = '/kaggle/working/van_confusion.png'
plt.savefig(char_confusion_path, dpi=300)
print(f"Character-wise confusion matrix grid saved to {char_confusion_path}")

# Log to WandB
wandb.log({"char_confusion_matrix_grid": wandb.Image(char_confusion_path)})
# Out:
#  View run <strong style="color:#cdcd00">char-wise-confusion</strong> at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/s31d7pvo' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/s31d7pvo</a><br> View project at: <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250519_163216-s31d7pvo/logs</code>
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250519_163457-mjb1f555</code>
# Syncing run <strong><a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/mjb1f555' target="_blank">char-wise-confusion</a></strong> to <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN</a>
#  View run at <a href='https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/mjb1f555' target="_blank">https://wandb.ai/ma24m004-iit-madras/DL_ASSIGNMENT_3_RNN/runs/mjb1f555</a>
# Character-wise confusion matrix grid saved to /kaggle/working/van_confusion.png

# %% [markdown]
# ## Model with attention
